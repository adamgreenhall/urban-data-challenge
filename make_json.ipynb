# %%
import pandas as pd
from utils import df_to_json, json

# %%
store = pd.HDFStore('data/san-francisco/data.hd5')
store
# Out:
# <class 'pandas.io.pytables.HDFStore'>
# File path: data/san-francisco/data.hd5
# /passenger_counts            frame        (shape->[513785,10])
# /schedule                    frame        (shape->[641063,4])
# /stops                       frame        (shape->[5586,5])

# %%
stops = store['stops']
schedule = store['schedule']
pcounts = store['passenger_counts']

# %% [markdown]
# # Stops map

# %%
# get the city's center for a map 
print(stops[['latitude', 'longitude']].mean().tolist())

# get the bounds
print(stops[['latitude', 'longitude']].min().tolist())
print(stops[['latitude', 'longitude']].max().tolist())
# Out:
# [37.76115761188684, -122.43510619226662]
# [37.705909999999996, -122.53922]
# [37.83607, -122.36972]

# %%
df_to_json(stops, 'web/stops_sf.json');

# %% [markdown]
# # Routes

# %%
routes = []
for route, route_stops in stops.reset_index().groupby('id_route').groups.iteritems():
    routes.append({'route': str(route),
         'stops': df_to_json(
            stops.ix[route_stops].sort(['direction_inbound', 'stop_seq']).reset_index().set_index(['direction_inbound', 'id_stop'])
          )
    })
with open('web/routes_sf.json', 'w+') as f: f.write(json.dumps(routes))

# %% [markdown]
# # Individual Route Timeseries Data

# %%
stops
# Out:
# <class 'pandas.core.frame.DataFrame'>
# MultiIndex: 5586 entries, (1, 3546) to (938, 7302)
# Data columns:
# stop_seq             5586  non-null values
# stop_name            5586  non-null values
# latitude             5586  non-null values
# longitude            5586  non-null values
# direction_inbound    5586  non-null values
# dtypes: float64(4), object(1)

# %%
schedule[schedule.id_route == 41].time_scheduled_arrival
# Out:
# 29294   2012-10-01 08:23:00.777000
# 29295   2012-10-01 08:05:00.785000
# 29296   2012-10-01 08:15:00.791000
# 29297   2012-10-01 07:57:00.800000
# 29301   2012-10-03 06:17:00.167000
# 29302   2012-10-03 06:04:00.174000
# 29303   2012-10-03 06:08:00.182000
# 29304   2012-10-03 06:14:00.189000
# 29305   2012-10-03 06:00:00.197000
# 29306   2012-10-03 06:25:00.204000
# 29307   2012-10-03 06:23:00.212000
# 29308   2012-10-03 06:19:00.220000
# 29488   2012-10-02 16:38:00.806000
# 29489   2012-10-02 16:11:00.815000
# 29490   2012-10-02 16:20:00.822000
# ...
# 632702   2012-10-08 16:51:00.155000
# 632703   2012-10-08 17:02:00.163000
# 632704   2012-10-08 17:13:00.172000
# 632705   2012-10-08 17:19:00.179000
# 632765   2012-10-08 17:06:00.188000
# 633476   2012-10-08 06:44:00.239000
# 633477   2012-10-08 06:36:00.247000
# 633478   2012-10-08 06:41:00.255000
# 635848   2012-10-08 16:50:00.632000
# 635849   2012-10-08 17:07:00.640000
# 635850   2012-10-08 17:03:00.647000
# 635851   2012-10-08 16:35:00.655000
# 635852   2012-10-08 16:44:00.663000
# 635853   2012-10-08 16:46:00.672000
# 635854   2012-10-08 16:57:00.679000
# Name: time_scheduled_arrival, Length: 3666

# %%
trip = pcounts[(pcounts.id_route == 41) & (pcounts.id_trip == 1627)]
trip_stops = stops[stops.reset_index().id_route == 41].reset_index().set_index('id_stop').sort(['direction_inbound', 'stop_seq'])

# should probably do this properly, in km:
# http://www.platoscave.net/blog/2009/oct/5/calculate-distance-latitude-longitude-python/
trip_stops['distance'] = (trip_stops[['latitude', 'longitude']].diff() ** 2).sum(axis=1).apply(np.sqrt).fillna(0).cumsum()

# trip.join(stops, on=['id_route', 'id_stop']) #.join(schedule.set_index(['id_route', 'id_trip']), on=['id_route', 'id_trip'])
df_to_json(trip.join(trip_stops['distance'], on='id_stop'), 'web/route_41.json')
# Out:
# [{'count': 0,
#   'count_boarding': 0,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.0,
#   'id_route': 41,
#   'id_stop': 5334,
#   'id_trip': 1627,
#   'index': 81507,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 21, 58),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 22, 10),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 17, 51)},
#  {'count': 0,
#   'count_boarding': 0,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.0018832153355359705,
#   'id_route': 41,
#   'id_stop': 5336,
#   'id_trip': 1627,
#   'index': 81508,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 24, 32),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 24, 32),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 24, 32)},
#  {'count': 8,
#   'count_boarding': 8,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.0,
#   'id_route': 41,
#   'id_stop': 5334,
#   'id_trip': 1627,
#   'index': 81509,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 26, 23),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 27, 19),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 26, 9)},
#  {'count': 12,
#   'count_boarding': 4,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.0018832153355359705,
#   'id_route': 41,
#   'id_stop': 5336,
#   'id_trip': 1627,
#   'index': 81510,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 29, 11),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 29, 11),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 27, 39)},
#  {'count': 12,
#   'count_boarding': 0,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.0047705670633302,
#   'id_route': 41,
#   'id_stop': 4445,
#   'id_trip': 1627,
#   'index': 81511,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 29, 38),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 29, 38),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 29, 38)},
#  {'count': 14,
#   'count_boarding': 2,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.005962078708252888,
#   'id_route': 41,
#   'id_stop': 6294,
#   'id_trip': 1627,
#   'index': 81512,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 30, 44),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 30, 55),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 30, 26)},
#  {'count': 14,
#   'count_boarding': 0,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.008819787580769949,
#   'id_route': 41,
#   'id_stop': 6290,
#   'id_trip': 1627,
#   'index': 81513,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 31, 17),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 31, 17),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 31, 17)},
#  {'count': 20,
#   'count_boarding': 6,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.010222713095529613,
#   'id_route': 41,
#   'id_stop': 6333,
#   'id_trip': 1627,
#   'index': 81514,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 33, 55),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 33, 55),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 32, 12)},
#  {'count': 23,
#   'count_boarding': 3,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.011533171030750305,
#   'id_route': 41,
#   'id_stop': 6928,
#   'id_trip': 1627,
#   'index': 81515,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 35, 21),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 35, 21),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 35, 10)},
#  {'count': 23,
#   'count_boarding': 0,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.01256414144739435,
#   'id_route': 41,
#   'id_stop': 4121,
#   'id_trip': 1627,
#   'index': 81516,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 35, 44),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 35, 44),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 35, 44)},
#  {'count': 23,
#   'count_boarding': 0,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.015781858029077892,
#   'id_route': 41,
#   'id_stop': 4111,
#   'id_trip': 1627,
#   'index': 81517,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 37, 34),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 37, 34),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 37, 34)},
#  {'count': 23,
#   'count_boarding': 0,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.01722407853927195,
#   'id_route': 41,
#   'id_stop': 4101,
#   'id_trip': 1627,
#   'index': 81518,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 38, 33),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 38, 33),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 38, 33)},
#  {'count': 23,
#   'count_boarding': 0,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.01900036680415819,
#   'id_route': 41,
#   'id_stop': 4108,
#   'id_trip': 1627,
#   'index': 81519,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 39, 47),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 40, 21),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 39, 7)},
#  {'count': 25,
#   'count_boarding': 3,
#   'count_exiting': 1,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.02061371735502767,
#   'id_route': 41,
#   'id_stop': 6750,
#   'id_trip': 1627,
#   'index': 81520,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 41, 6),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 41, 26),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 40, 49)},
#  {'count': 25,
#   'count_boarding': 0,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.02329226173584557,
#   'id_route': 41,
#   'id_stop': 6773,
#   'id_trip': 1627,
#   'index': 81521,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 42),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 42),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 42)},
#  {'count': 25,
#   'count_boarding': 0,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.024615968652051345,
#   'id_route': 41,
#   'id_stop': 6783,
#   'id_trip': 1627,
#   'index': 81522,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 42, 34),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 42, 34),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 42, 29)},
#  {'count': 25,
#   'count_boarding': 0,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.0264287289781901,
#   'id_route': 41,
#   'id_stop': 6762,
#   'id_trip': 1627,
#   'index': 81523,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 43, 11),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 43, 11),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 43, 11)},
#  {'count': 23,
#   'count_boarding': 1,
#   'count_exiting': 3,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.028283156113436705,
#   'id_route': 41,
#   'id_stop': 6768,
#   'id_trip': 1627,
#   'index': 81524,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 43, 48),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 43, 48),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 43, 41)},
#  {'count': 23,
#   'count_boarding': 0,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.029311407055595925,
#   'id_route': 41,
#   'id_stop': 6760,
#   'id_trip': 1627,
#   'index': 81525,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 44, 4),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 44, 4),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 44, 4)},
#  {'count': 23,
#   'count_boarding': 0,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.031295972499199784,
#   'id_route': 41,
#   'id_stop': 6766,
#   'id_trip': 1627,
#   'index': 81526,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 44, 39),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 44, 39),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 44, 32)},
#  {'count': 20,
#   'count_boarding': 0,
#   'count_exiting': 3,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.03332990956804821,
#   'id_route': 41,
#   'id_stop': 6779,
#   'id_trip': 1627,
#   'index': 81527,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 45, 37),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 45, 37),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 45, 27)},
#  {'count': 21,
#   'count_boarding': 1,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.03506729265763516,
#   'id_route': 41,
#   'id_stop': 6786,
#   'id_trip': 1627,
#   'index': 81528,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 46, 50),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 47, 10),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 46, 41)},
#  {'count': 16,
#   'count_boarding': 0,
#   'count_exiting': 5,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.03782830696399683,
#   'id_route': 41,
#   'id_stop': 6756,
#   'id_trip': 1627,
#   'index': 81529,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 47, 51),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 48, 9),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 47, 40)},
#  {'count': 13,
#   'count_boarding': 0,
#   'count_exiting': 3,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.04113508787600612,
#   'id_route': 41,
#   'id_stop': 6770,
#   'id_trip': 1627,
#   'index': 81530,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 48, 56),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 48, 56),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 48, 49)},
#  {'count': 13,
#   'count_boarding': 0,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.04286910056339335,
#   'id_route': 41,
#   'id_stop': 7056,
#   'id_trip': 1627,
#   'index': 81531,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 49, 31),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 49, 31),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 49, 31)},
#  {'count': 10,
#   'count_boarding': 0,
#   'count_exiting': 3,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.04662859521028849,
#   'id_route': 41,
#   'id_stop': 6754,
#   'id_trip': 1627,
#   'index': 81532,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 50, 38),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 50, 38),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 50, 28)},
#  {'count': 10,
#   'count_boarding': 0,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.048137104408132236,
#   'id_route': 41,
#   'id_stop': 6781,
#   'id_trip': 1627,
#   'index': 81533,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 51, 14),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 51, 14),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 51, 14)},
#  {'count': 10,
#   'count_boarding': 0,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.04977197443354953,
#   'id_route': 41,
#   'id_stop': 6777,
#   'id_trip': 1627,
#   'index': 81534,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 51, 44),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 51, 44),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 51, 44)},
#  {'count': 7,
#   'count_boarding': 0,
#   'count_exiting': 3,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.05275259517426996,
#   'id_route': 41,
#   'id_stop': 6752,
#   'id_trip': 1627,
#   'index': 81535,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 52, 44),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 53, 5),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 52, 36)},
#  {'count': 5,
#   'count_boarding': 0,
#   'count_exiting': 2,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.056204739435455724,
#   'id_route': 41,
#   'id_stop': 6745,
#   'id_trip': 1627,
#   'index': 81536,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 53, 51),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 54, 23),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 53, 46)},
#  {'count': 5,
#   'count_boarding': 0,
#   'count_exiting': 0,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.05751018954940241,
#   'id_route': 41,
#   'id_stop': 3024,
#   'id_trip': 1627,
#   'index': 81537,
#   'time_door_close': datetime.datetime(2012, 10, 1, 16, 55, 47),
#   'time_pullout': datetime.datetime(2012, 10, 1, 16, 56, 21),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 54, 37)},
#  {'count': 3,
#   'count_boarding': 0,
#   'count_exiting': 2,
#   'date': datetime.datetime(2012, 10, 1, 0, 0),
#   'distance': 0.058930506415453186,
#   'id_route': 41,
#   'id_stop': 5331,
#   'id_trip': 1627,
#   'index': 81538,
#   'time_door_close': datetime.datetime(2012, 10, 1, 17, 5, 36),
#   'time_pullout': datetime.datetime(2012, 10, 1, 17, 6, 12),
#   'time_stop': datetime.datetime(2012, 10, 1, 16, 57, 22)}]
